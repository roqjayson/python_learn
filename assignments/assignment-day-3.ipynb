# %% [markdown]
# # Python Assignment: Simple Note Taker
#
# This program will be able to perform the following:
#
# 1. Allow you to log data entries.
# 2. View all logged data.
# 3. Save logged data to a file.
# 4. Load logged data from a file.
# 5. Calculate basic statistics (mean and maximum) on the data.
#
# ## Project Overview
#
# 1. Main Program (data_logger): Provides a user interface and handles interactions with the data logger.
# 2. Data Manager Module (data_manager): Manages the data entries and performs file operations and calculations.
#
# ***
#
# Send it via email before 13 Sept 2024:
#
# **To**: roquejayson0@gmail.com
#
# **CC**: excelhelplineph@gmail.com
#
# **Subject**: Assigment_fullname.py - Day 3
#
# ***
#
# ## Step-by-Step Implementation
#
# 1. Define the Data Manager Module
#
# Create a class called `DataManager` and then convert the script into a utility script called `data_manager` to use it as a module on the next step.

# %%
class ____: # Name this DataManager
    def ____(self): # initialize the attribute
        self.data = []

    def ____(self, value): # name this method add_data
        try:
            number = float(value)
            self.data.____(number) # use appropriate method to add an item to the empty list
            print("Data added successfully!")
        except ValueError:
            print("Invalid input. Please enter a numerical value.")

    def ____(self): # name this method view_data
        if not self.data:
            print("No data available.")
        else:
            print("Logged Data:")
            for i, value in enumerate(self.data, 1):
                print(f"Entry {i}: {value}")

    def ____(self, filename): # name this method save_to_file
        with open(filename, ____) as file: # add the correct mode for writing data
            for number in self.data:
                file.____(f"{number}\n") # use the correct method to write data
        print(f"Data saved to {filename}")

    def ____(self, filename): # name this method load_from_file
        try:
            with open(filename, 'r') as file:
                self.data = [float(line.strip()) for line in file]
            print(f"Data loaded from {filename}")
        except FileNotFoundError:
            print("File not found. Starting with an empty data list.")
        except ValueError:
            print("File contains non-numeric data. Please check the file.")

    def calculate_statistics(self):
        if not self.data:
            print("No data available for analysis.")
            return
        mean_value = ____(self.data) / ____(self.data) # add the right operation by getting the sum of self.data divided by the length of self.data
        max_value = ____(self.data)# use the correct function to get the maximum self.data
        print(f"Mean: {mean_value____}") # should have 2 decimal places only
        print(f"Max: {max_value}")

# %% [markdown]
# - `add_data` method: Adds a numerical entry to the data list.
# - `view_data` method: Displays all logged data entries.
# - `save_to_file` method: Saves data entries to a file.
# - `load_from_file` method: Loads data entries from a file.
# - `calculate_statistics` method: Calculates and displays the mean and maximum of the data entries.

# %% [markdown]
# 2. Create the main program

# %%
from ____ import ____ # use the module name and then import the class name

def ____(): # add the function name display_menu
    print("\nData Logger Menu")
    print("1. Add Data Entry")
    print("2. View Data Entries")
    print("3. Save Data")
    print("4. Load Data")
    print("5. Calculate Statistics")
    print("6. Exit")

def main():
    manager = DataManager()
    
    """At this point, you are required to put in a logic where it can perform the following:
    1. Ask for a user input, so that the user can choose from 1 to 6
    2. If the user chose 1, then they should be asked to put in a numerical value.
    2.1 The numerical value they put will be processed in the add_data method
    3. If the user chose 2, then the view_data method will execute
    4. If the user chose 3, then they will be asked to add a filename to the new file.
    4.1 After the user inputs the filename, it will then execute the save_to_file method
    5. If the user chose 4, then it will execute load_from_file method
    6. If the user chose 5, then it should execute calculate_statistics method
    7. If the user chose 6, then it should print something that tells the user that the program is exiting
    7.1 and then the program should break.
    8. If the user chose a number outside of the menu range, then it should inform the user that they chose an invalid number"""

# %% [markdown]
# ### Example Expected Result
#
# #### User chose 1
#
#
# ![image.png](attachment:618dc866-c988-483e-9c36-7af3537a2719.png)
#
# ***

# %% [markdown]
# #### User chose 2
#
# We see the entry they added when they chose 1
#
#
# ![image.png](attachment:781a03b8-3dd7-4b99-ab43-36073bd3f108.png)
#
# ***

# %% [markdown]
# #### User chose 3
#
# ![image.png](attachment:f3ba7f3e-0ac6-4754-a50a-d704645a8d7a.png)
#
# ##### Output now shows the new file saved
#
# ![image.png](attachment:bd602046-553d-409a-894e-44e908f25ed3.png)
#
# ***

# %% [markdown]
# #### User chose 4
#
# ![image.png](attachment:c4341f6e-30a7-4bfa-a213-696ecd3a8274.png)
#
# If the user has another file apart from test, they should be able to access the data in that file.
#
# ***

# %% [markdown]
# #### User chose 5
#
# ![image.png](attachment:cdf841a4-b716-408d-9d1a-305a063e7ba0.png)
#
#
# ***

# %% [markdown]
# #### User chose 6
#
# ![image.png](attachment:91bf50ac-84fb-46bd-83a0-9699279c7878.png)
#
# ***
